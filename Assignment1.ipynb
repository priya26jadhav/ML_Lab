# %%
import pandas as pd
import numpy as np
# reading of csv file
df = pd.read_csv("C:/Users/priya/Downloads/ali_express_2024_winter_jackets.csv")
# it will display first 5 records
df.head()
# Out:
#                                                title tradeAmount  averageStar  \
# 0  Winter Padded Cotton Coat Female New Korean Ve...     68 sold          0.0
# 1  2024 Women Parkas Winter Casual Long Coats Jac...     14 sold          5.0
# 2  Faux Fur Woman Jacket Hooded Drawstring Parka ...      1 sold          0.0
# 3  2023 New Down Cotton Vest Women Autumn Winter ...   800+ sold          4.5
# 4  New Winter Women Parka Hooded Jackets Thicken ...     43 sold          0.0
#
#    wishedCount  quantity  AverageDiscountPrice  MinDiscountPrice  \
# 0          309     17726             18.412000             16.31
# 1           46     23969             42.540000             42.54
# 2            3       599             25.445667             24.28
# 3         1585    485033             11.981977              2.06
# 4          112     32651             15.250000             15.25
#
#    MaxDiscountPrice
# 0             27.34
# 1             42.54
# 2             26.62
# ...

# %%
# returns colunms
df.columns
# Out:
# Index(['title', 'tradeAmount', 'averageStar', 'wishedCount', 'quantity',
#        'AverageDiscountPrice', 'MinDiscountPrice', 'MaxDiscountPrice'],
#       dtype='object')

# %%
# returns data type of each varible
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 109 non-null    object
#  1   tradeAmount           109 non-null    object
#  2   averageStar           109 non-null    float64
#  3   wishedCount           109 non-null    int64
#  4   quantity              109 non-null    int64
#  5   AverageDiscountPrice  109 non-null    float64
#  6   MinDiscountPrice      109 non-null    float64
#  7   MaxDiscountPrice      109 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 6.9+ KB

# %%
# returns dimensions of the data set
df.shape
# Out:
# (109, 6)

# %%
df.loc[df.isna().any(axis="columns")]
# Out:
# Empty DataFrame
# Columns: [title, tradeAmount, averageStar, wishedCount, quantity, AverageDiscountPrice, MinDiscountPrice, MaxDiscountPrice]
# Index: []

# %%
df['title'].is_unique
df['quantity'].is_unique
# Out:
# False

# %%
# to drop rhe column
to_drop = ['wishedCount']
df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#                                                title tradeAmount  averageStar  \
# 0  Winter Padded Cotton Coat Female New Korean Ve...     68 sold          0.0
# 1  2024 Women Parkas Winter Casual Long Coats Jac...     14 sold          5.0
# 2  Faux Fur Woman Jacket Hooded Drawstring Parka ...      1 sold          0.0
# 3  2023 New Down Cotton Vest Women Autumn Winter ...   800+ sold          4.5
# 4  New Winter Women Parka Hooded Jackets Thicken ...     43 sold          0.0
#
#    quantity  AverageDiscountPrice  MinDiscountPrice  MaxDiscountPrice
# 0     17726             18.412000             16.31             27.34
# 1     23969             42.540000             42.54             42.54
# 2       599             25.445667             24.28             26.62
# 3    485033             11.981977              2.06             21.36
# 4     32651             15.250000             15.25             15.25

# %%
# returns the first 30 records
df.head(30)
# Out:
#                                                 title  tradeAmount  \
# 0   Winter Padded Cotton Coat Female New Korean Ve...      68 sold
# 1   2024 Women Parkas Winter Casual Long Coats Jac...      14 sold
# 2   Faux Fur Woman Jacket Hooded Drawstring Parka ...       1 sold
# 3   2023 New Down Cotton Vest Women Autumn Winter ...    800+ sold
# 4   New Winter Women Parka Hooded Jackets Thicken ...      43 sold
# 5   Down Jacket Men White Duck Winter Coat Windpro...    500+ sold
# 6   Winter Clothes Women Heavy Jackets Coat Women ...    800+ sold
# 7   Thick Down Cotton-Padded Jacket Jackets Women ...       0 sold
# 8   Casual Short Winter Jacket Women Stand Collar ...  1,000+ sold
# 9   CHIC VEN Women's Jackets Vintage Fashion Lapel...       4 sold
# 10  Winter Women Jacket Parka Clothes Fur Collar W...    800+ sold
# 11  Thicken Autumn Winter Jackets Women Cotton-Pad...       6 sold
# 12  2024 Winter Women Jacket Warm Black Hooded Zip...      52 sold
# ...

# %%
# columns with data types
df.dtypes
# Out:
# title                    object
# tradeAmount              object
# averageStar             float64
# quantity                  int64
# AverageDiscountPrice    float64
# MinDiscountPrice        float64
# MaxDiscountPrice        float64
# dtype: object

# %%
# returning first 5 records with only avg discount price
df['AverageDiscountPrice'].head()
# Out:
# 0    18.412000
# 1    42.540000
# 2    25.445667
# 3    11.981977
# 4    15.250000
# Name: AverageDiscountPrice, dtype: float64
